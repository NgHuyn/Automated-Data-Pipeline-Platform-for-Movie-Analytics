# %%
import os
import psycopg2
import pandas as pd

# Connect to the PostgreSQL database
conn = psycopg2.connect(
    dbname=os.getenv('POSTGRES_DB'),
    user=os.getenv('POSTGRES_USER'),
    password=os.getenv('POSTGRES_PASSWORD'),
    host=os.getenv('localhost'),  
    port=os.getenv('POSTGRES_PORT', '5432')
)

# %%
# Create a cursor object
cursor = conn.cursor()

# Fetch data from the review table
cursor.execute("SELECT * FROM review;")
rows = cursor.fetchall()

# Get column names
colnames = [desc[0] for desc in cursor.description]

# Create a DataFrame
df = pd.DataFrame(rows, columns=colnames)
df
# Out:
#       movie_id review_summary  \
# 0      1097870     No summary
# 1      1097870     No summary
# 2      1097870     No summary
# 3      1097870     No summary
# 4      1097870     No summary
# ...        ...            ...
# 4555   1304011     No summary
# 4556   1299969     No summary
# 4557   1372871     No summary
# 4558   1225155     No summary
# 4559   1265445     No summary
#
#                                             review_text  rating  \
# 0     Better than expected, but still not great. Thi...     5.0
# 1     I don't have cable or anything to keep me up t...     8.0
# 2                                            No content     6.0
# 3                                            No content     1.0
# 4     Starts out cute. A sweet little dyslexic boy a...     1.0
# ...                                                 ...     ...
# 4555                                         No content     4.0
# 4556  The documentary on Mysteryland offers a captiv...     9.0
# 4557  Director and writer A. Sesay delivers the comp...     8.0
# 4558  Poignant, funny, touching, heartwarming and so...    10.0
# 4559  This was a short film that I got the chance to...     7.0
#
#                    author        date  helpful  not_helpful
# 0            SpaaceMonkee  2024-11-29      0.0          0.0
# 1             birchsandra  2024-11-28      0.0          0.0
# 2          bostonactorted  2024-11-28      0.0          0.0
# 3                  pbgvyx  2024-11-28      2.0          0.0
# 4                   pjrag  2024-11-28      2.0          2.0
# ...                   ...         ...      ...          ...
# 4555        wpymwonktnawi  2024-06-27      2.0          0.0
# 4556             kmfrmbdx  2024-06-09      0.0          2.0
# 4557            LADSteele  2024-10-21      0.0          0.0
# 4558          judyz-03198  2024-09-18      1.0          0.0
# 4559  Reviews_of_the_Dead  2024-07-21      1.0          0.0
#
# [4560 rows x 8 columns]

# %%
# Export the DataFrame to a CSV file
csv_file_path = 'reviews.csv'
df.to_csv(csv_file_path, index=False)

# Close the cursor and connection
cursor.close()
conn.close()

print(f"Data exported to {csv_file_path}")
# Out:
# Data exported to reviews.csv
